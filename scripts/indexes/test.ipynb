# %%
import psycopg2
import pandas.io.sql as psql
from queries.set_price import querySet, querySetCards
import pandas as pd

    conn = psycopg2.connect(dbname='d4glguq0as3fe6', user='ucjrvhda1pfbv1', password='pa045091d3e285537e8a31eb863c11df1dfa42659a9a447ce231b18f0070892a1', host='ec2-34-195-123-119.compute-1.amazonaws.com', port='5432', sslmode='require')
    cur = conn.cursor()
    df1 = psql.read_sql(querySet, conn)
    df = psql.read_sql(querySetCards, conn)
    print('Connection Established')

    df.date=pd.to_datetime(df.date)#Coaerce Date to Datetime
    df2 = df.groupby('name')['date'].agg(['min','max']).rename(columns={'min':'first','max':'last'}).stack().reset_index()
    df2.columns = ['name', 'price','date']
    df2.set_index(df2.date, inplace=True)#Set Date as index
    df2.columns = ['name', 'price','date']
    df2.index.name = None
    df3 = df.merge(df2, how='outer')
    df4 = df3.dropna()
    df4 = df4.reset_index(drop = True)
    df4['Set Number'] = df4['number']
    df5 = df4.drop(columns=['abbreviation','number'])
    df_first = df5[df5['price']=='first']
    df_first.columns = ['Date', 'Market','product_id','Name','price','Set Number', 'Set Name']
    df_last = df5[df5['price']=='last']
    df_last.columns = ['Date', 'Market','product_id','Name','price','Set Number', 'Set Name']
    df_last2 = df_last.drop(columns=['Name','Set Number','price', 'Set Name'])
    df6 = df_first.merge(df_last2, left_on='product_id', right_on='product_id')
    df6.columns = ['Date (1)','Price (1)','Product Id','Name','Price','Set Number','Set Name', 'Date (2)','Price (2)']
    df7 = df6.drop(columns=['Price','Product Id'])
    df7['% Change'] = (( df7['Price (2)'] - df7['Price (1)'] ) / df7['Price (1)'])*100
    df8= df7.round(2)
    df9 = pd.DataFrame({'Name':['Name'],'Set Number':['Set Number'],'Set Name':['Set Name'],'Price (1)':['Price (1)'],'Date (1)':['Date (1)'],'Price (2)':['Price (2)'],'Date (2)':['Date (2)'],'% Change':['% Change']}, index=[0])
    df9 = df9.append(df8,sort= False)
    df9 = df9.reset_index(drop=True)
    df9['Date (1)'] = df9['Date (1)'].astype(str)
    df9['Date (2)'] = df9['Date (2)'].astype(str)
    df9['Date (1)'] = df9['Date (1)'].str[:11]
    df9['Date (2)'] = df9['Date (2)'].str[:11]
    df9.to_csv(r'/home/tier1marketspace/youtuberReport/scripts/data/setDataCards_final.csv', encoding='utf-8', index=False)
    df1.to_csv(r'/home/tier1marketspace/youtuberReport/scripts/data/setData.csv', encoding='utf-8', index=False)
    cur.close()
    conn.close()
    print('Connection Closed')

# %%
import psycopg2
import pandas.io.sql as psql
from queries.set_price import querySet, querySetCards
import pandas as pd

conn = psycopg2.connect(dbname='d4glguq0as3fe6', user='ucjrvhda1pfbv1', password='pa045091d3e285537e8a31eb863c11df1dfa42659a9a447ce231b18f0070892a1', host='ec2-34-195-123-119.compute-1.amazonaws.com', port='5432', sslmode='require')
cur = conn.cursor()
df1 = psql.read_sql(querySet, conn)
df = psql.read_sql(querySetCards, conn)

# %%
import psycopg2
import pandas.io.sql as psql
from queries.set_price import querySet, querySetCards
import pandas as pd

conn = psycopg2.connect(dbname='d4glguq0as3fe6', user='ucjrvhda1pfbv1', password='pa045091d3e285537e8a31eb863c11df1dfa42659a9a447ce231b18f0070892a1', host='ec2-34-195-123-119.compute-1.amazonaws.com', port='5432', sslmode='require')
cur = conn.cursor()
df1 = psql.read_sql(querySet, conn)
df = psql.read_sql(querySetCards, conn)
df.date=pd.to_datetime(df.date)#Coaerce Date to Datetime
df2 = df.groupby('name')['date'].agg(['min','max']).rename(columns={'min':'first','max':'last'}).stack().reset_index()
df2.columns = ['name', 'price','date']
df2.set_index(df2.date, inplace=True)#Set Date as index
df2.columns = ['name', 'price','date']
df2.index.name = None
df3 = df.merge(df2, how='outer')
df4 = df3.dropna()
df4 = df4.reset_index(drop = True)
df4['Set Number'] = df4['number']
df5 = df4.drop(columns=['abbreviation','number'])
df_first = df5[df5['price']=='first']
df_first.columns = ['Date', 'Market','product_id','Name','Set Name','price', 'Set Number']
df_last = df5[df5['price']=='last']
df_last.columns = ['Date', 'Market','product_id','Name','Set Name','price', 'Set Number']
df_last2 = df_last.drop(columns=['Name','Set Number','price', 'Set Name'])
df6 = df_first.merge(df_last2, left_on='product_id', right_on='product_id')
df6.columns = ['Date (1)','Price (1)','Product Id','Name','Set Name','price','Set Number', 'Date (2)','Price (2)']
df7 = df6.drop(columns=['price','Product Id'])
df7['% Change'] = (( df7['Price (2)'] - df7['Price (1)'] ) / df7['Price (1)'])*100
df8= df7.round(2)
df9 = pd.DataFrame({'Name':['Name'],'Set Number':['Set Number'],'Set Name':['Set Name'],'Price (1)':['Price (1)'],'Date (1)':['Date (1)'],'Price (2)':['Price (2)'],'Date (2)':['Date (2)'],'% Change':['% Change']}, index=[0])
df9 = df9.append(df8,sort= False)
df9 = df9.reset_index(drop=True)
df9['Date (1)'] = df9['Date (1)'].astype(str)
df9['Date (2)'] = df9['Date (2)'].astype(str)
df9['Date (1)'] = df9['Date (1)'].str[:11]
df9['Date (2)'] = df9['Date (2)'].str[:11]
df10 = df9.iloc[1: , :]
df10
# Out:
#                                                    Name  Set Number  \
# 1               Arcana Triumph Joker (Collector's Rare)  KICO-EN001
# 2                     Joker's Knight (Collector's Rare)  KICO-EN002
# 3                   Joker's Straight (Collector's Rare)  KICO-EN004
# 4     Number F0: Utopic Draco Future (Collector's Rare)  KICO-EN013
# 5     Gilti-Gearfried the Magical Steel Knight (Coll...  KICO-EN014
# 6                       Hyper Galaxy (Collector's Rare)  KICO-EN021
# 7                     Queen's Knight (Collector's Rare)  KICO-EN026
# 8                      King's Knight (Collector's Rare)  KICO-EN027
# 9                      Jack's Knight (Collector's Rare)  KICO-EN028
# 10                     Rescue Rabbit (Collector's Rare)  KICO-EN034
# 11                 Number 39: Utopia (Collector's Rare)  KICO-EN042
# 12         Reinforcement of the Army (Collector's Rare)  KICO-EN051
# 13                   Lightning Storm (Collector's Rare)  KICO-EN057
# 14               Rivalry of Warlords (Collector's Rare)  KICO-EN058
# 15        Slifer the Sky Dragon (Secret Pharaoh's Rare)  KICO-EN063
# 16         Slifer the Sky Dragon (Ultra Pharaoh's Rare)  KICO-EN063
# 17         Obelisk the Tormentor (Ultra Pharaoh's Rare)  KICO-EN064
# 18        Obelisk the Tormentor (Secret Pharaoh's Rare)  KICO-EN064
# 19      The Winged Dragon of Ra (Secret Pharaoh's Rare)  KICO-EN065
# 20       The Winged Dragon of Ra (Ultra Pharaoh's Rare)  KICO-EN065
# 21                    Imperial Bower (Collector's Rare)  KICO-EN003
# 22                               Beetrooper Scout Buggy  DAMA-EN000
# 23                                    Stardust Synchron  DAMA-EN002
# 24                                       Stardust Trail  DAMA-EN003
# 25                                       Despian Comedy  DAMA-EN004
# 26                                      Despian Tragedy  DAMA-EN005
# 27                          Aluber the Jester of Despia  DAMA-EN006
# 28                                 Dramaturge of Despia  DAMA-EN007
# 29                                   The Iris Swordsoul  DAMA-EN009
# 30                     Clavkiys, the Magikey Skyblaster  DAMA-EN010
# ...                                                 ...         ...
# 1416                                  The Wicked Avatar  KICO-EN061
# 1417                                  The Wicked Eraser  KICO-EN062
# 1418                                   Tindangle Dholes  KICO-EN016
# 1419                               Morph King Stygi-Gel  KICO-EN018
# 1420                                       Burning Soul  KICO-EN020
# 1421                                  Pendulum Transfer  KICO-EN022
# 1422                                       Pendulum Xyz  KICO-EN023
# 1423                                     Dowsing Fusion  KICO-EN024
# 1424                                     Queen's Knight  KICO-EN026
# 1425                                      King's Knight  KICO-EN027
# 1426                                      Jack's Knight  KICO-EN028
# 1427                                Arcana Knight Joker  KICO-EN029
# 1428                                 Arcana Extra Joker  KICO-EN030
# 1429                                  Gravekeeper's Spy  KICO-EN031
# 1430                                    Majestic Dragon  KICO-EN032
# 1431                                  Stardust Xiaolong  KICO-EN033
# 1432                               ZW - Ultimate Shield  KICO-EN036
# 1433                                    ZW - Eagle Claw  KICO-EN037
# 1434                                        Cloudcastle  KICO-EN039
# 1435                 Baxia, Brightness of the Yang Zing  KICO-EN040
# 1436                                  Number 39: Utopia  KICO-EN042
# 1437                           Wind-Up Arsenal Zenmaioh  KICO-EN044
# 1438                                     Infinite Cards  KICO-EN050
# 1439                        The Warrior Returning Alive  KICO-EN052
# 1440                               Ties of the Brethren  KICO-EN053
# 1441                                     Pot of Duality  KICO-EN054
# 1442                                     Unexpected Dai  KICO-EN055
# 1443                                  Converging Wishes  KICO-EN059
# 1444                                  Scrap Twin Dragon  KICO-EN038
# 1445                 Chaofeng, Phantom of the Yang Zing  KICO-EN041
#
#              Set Name Price (1)     Date (1) Price (2)     Date (2) % Change
# 1         Kings Court     60.77  2021-08-14      55.49  2021-11-22     -8.69
# 2         Kings Court      52.5  2021-08-14       45.9  2021-11-22    -12.57
# 3         Kings Court     27.63  2021-08-14      25.92  2021-11-22     -6.19
# 4         Kings Court     84.32  2021-08-14     135.14  2021-11-22     60.27
# 5         Kings Court     21.44  2021-08-14      45.02  2021-11-22    109.98
# 6         Kings Court     20.85  2021-08-14      16.03  2021-11-22    -23.12
# 7         Kings Court     44.67  2021-08-14      44.49  2021-11-22      -0.4
# 8         Kings Court      38.8  2021-08-14      40.84  2021-11-22      5.26
# 9         Kings Court     35.21  2021-08-14      34.32  2021-11-22     -2.53
# 10        Kings Court     51.65  2021-08-14      46.37  2021-11-22    -10.22
# 11        Kings Court     56.47  2021-08-14      36.21  2021-11-22    -35.88
# 12        Kings Court     94.29  2021-08-14     103.45  2021-11-22      9.71
# 13        Kings Court     98.12  2021-08-14     142.65  2021-11-22     45.38
# 14        Kings Court     49.05  2021-08-14      79.06  2021-11-22     61.18
# 15        Kings Court    514.88  2021-08-14     321.72  2021-11-22    -37.52
# 16        Kings Court     82.64  2021-08-14      54.14  2021-11-22    -34.49
# 17        Kings Court     69.43  2021-08-14      35.26  2021-11-22    -49.22
# 18        Kings Court    365.56  2021-08-14     140.93  2021-11-22    -61.45
# 19        Kings Court    320.63  2021-08-14     192.25  2021-11-22    -40.04
# 20        Kings Court     73.49  2021-08-14      44.17  2021-11-22     -39.9
# 21        Kings Court     27.09  2021-08-14      22.57  2021-11-22    -16.69
# 22    Dawn of Majesty     11.94  2021-08-14      12.27  2021-11-22      2.76
# 23    Dawn of Majesty     16.09  2021-08-14      16.25  2021-11-22      0.99
# 24    Dawn of Majesty      0.13  2021-08-14       0.08  2021-11-22    -38.46
# 25    Dawn of Majesty      0.19  2021-08-14       0.24  2021-11-22     26.32
# 26    Dawn of Majesty      0.11  2021-08-14       0.05  2021-11-22    -54.55
# 27    Dawn of Majesty     43.21  2021-08-14      38.43  2021-11-22    -11.06
# 28    Dawn of Majesty      6.62  2021-08-14       6.71  2021-11-22      1.36
# 29    Dawn of Majesty     28.04  2021-08-14      16.84  2021-11-22    -39.94
# 30    Dawn of Majesty      0.14  2021-08-14       0.13  2021-11-22     -7.14
# ...               ...       ...          ...       ...          ...      ...
# 1416      Kings Court     10.28  2021-07-03       0.06  2021-11-22    -99.42
# 1417      Kings Court      8.59  2021-07-03       0.05  2021-11-22    -99.42
# 1418      Kings Court      2.76  2021-07-04       0.09  2021-11-22    -96.74
# 1419      Kings Court     21.95  2021-07-04       0.26  2021-11-22    -98.82
# 1420      Kings Court     21.95  2021-07-04       1.48  2021-11-22    -93.26
# 1421      Kings Court      1.38  2021-07-04       0.05  2021-11-22    -96.38
# 1422      Kings Court      1.23  2021-07-04       0.06  2021-11-22    -95.12
# 1423      Kings Court      1.15  2021-07-04       0.04  2021-11-22    -96.52
# 1424      Kings Court      0.23  2021-07-04       0.08  2021-11-22    -65.22
# 1425      Kings Court      0.23  2021-07-04       0.07  2021-11-22    -69.57
# 1426      Kings Court      0.23  2021-07-04       0.08  2021-11-22    -65.22
# 1427      Kings Court      0.28  2021-07-04       0.06  2021-11-22    -78.57
# 1428      Kings Court      0.22  2021-07-04       0.05  2021-11-22    -77.27
# 1429      Kings Court      0.23  2021-07-04       0.18  2021-11-22    -21.74
# 1430      Kings Court      0.36  2021-07-04       0.08  2021-11-22    -77.78
# 1431      Kings Court      0.27  2021-07-04       0.06  2021-11-22    -77.78
# 1432      Kings Court      0.28  2021-07-04       0.03  2021-11-22    -89.29
# 1433      Kings Court       0.3  2021-07-04       0.05  2021-11-22    -83.33
# 1434      Kings Court      0.24  2021-07-04        0.1  2021-11-22    -58.33
# 1435      Kings Court      0.25  2021-07-04       0.25  2021-11-22         0
# 1436      Kings Court      0.25  2021-07-04       0.14  2021-11-22       -44
# 1437      Kings Court      0.33  2021-07-04        0.1  2021-11-22     -69.7
# 1438      Kings Court      0.27  2021-07-04       0.06  2021-11-22    -77.78
# 1439      Kings Court      0.29  2021-07-04        0.1  2021-11-22    -65.52
# 1440      Kings Court      0.27  2021-07-04       0.04  2021-11-22    -85.19
# 1441      Kings Court      0.67  2021-07-04       0.42  2021-11-22    -37.31
# 1442      Kings Court      0.28  2021-07-04       0.25  2021-11-22    -10.71
# 1443      Kings Court      0.23  2021-07-04       0.05  2021-11-22    -78.26
# 1444      Kings Court      0.18  2021-07-05       0.12  2021-11-22    -33.33
# 1445      Kings Court      1.02  2021-07-05       0.27  2021-11-22    -73.53
#
# [1445 rows x 8 columns]
